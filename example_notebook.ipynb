# %% [markdown]
# # Example notebook to read datasets
#
# The goal is to demonstrate how to read datasets for the Kings Creek watershed, implement simple computations (e.g., soil water storage), and plot some of the time series and maps.

# %%
# Import modules
import glob
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
import matplotlib.pyplot as plt
